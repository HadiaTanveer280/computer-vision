# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = "C:/Users/jk/Desktop/images.jpeg"  # Replace with the path to your image
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert the image to float32
gray_float = np.float32(gray)

# Apply Harris Corner Detection
dst = cv2.cornerHarris(src=gray_float, blockSize=2, ksize=3, k=0.04)

# Dilate corner points for better visibility
dst = cv2.dilate(dst, None)

# Threshold to identify strong corners
img[dst > 0.01 * dst.max()] = [0, 0, 255]

# Display the results
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Harris Corner Detection")
plt.axis("off")
plt.show()
